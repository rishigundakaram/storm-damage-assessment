# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

import rasterio
from osgeo import gdal
import geopandas as gpd

# Visualisation
from matplotlib import pyplot as plt
import matplotlib.image as img
from matplotlib.pyplot import figure
from PIL import Image

# %%
shp = gpd.read_file('../data/building_footprints/building_footprint_roi_challenge.shp')

# %%
shp.head()

# %%
# Plot the building footprints
fig, ax = plt.subplots(figsize=(10, 10))  # Adjust the figure size as needed
shp.plot(ax=ax, color='blue', edgecolor='black')  # You can customize colors

plt.title('Building Footprints')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
from shapely.geometry import box

post_event_image ='../data/raw/Post_Event_San_Juan.tif'
with rasterio.open(post_event_image) as src:
    bounds = src.bounds
    crs = src.crs

# Create a Polygon from the bounds
tiff_polygon = box(bounds.left, bounds.bottom, bounds.right, bounds.top)

# Convert the Polygon into a GeoDataFrame
tiff_gdf = gpd.GeoDataFrame({'geometry': [tiff_polygon]}, crs=crs)



# Ensure the building footprints are in the same CRS as the TIFF file
building_footprints_gdf = shp.to_crs(crs)

intersects = building_footprints_gdf.intersects(tiff_polygon)
print(sum(intersects))
print(len(building_footprints_gdf))
# Plotting
# fig, ax = plt.subplots(figsize=(10, 10))
# tiff_gdf.plot(ax=ax, facecolor="none", edgecolor='red', linewidth=2, label='TIFF Extent')
# building_footprints_gdf.plot(ax=ax, color='blue', edgecolor='black', alpha=0.5, label='Building Footprints')

# plt.title('TIFF Extent and Building Footprints')
# plt.xlabel('Longitude')
# plt.ylabel('Latitude')
# plt.legend()
# plt.show()

# %%
from osgeo import gdal, osr, ogr

# Open the GeoTIFF file
tif_ds = gdal.Open(post_event_image, gdal.GA_ReadOnly)

# Get the spatial reference
tif_srs = tif_ds.GetProjectionRef()

# Print the WKT SRS
print("GeoTIFF WKT SRS:\n", tif_srs)

# Open the shapefile
shp_file_path = '/home/projects/storm-damage/data/building_footprints/building_footprint_roi_challenge.shp'
new_shp_file_path = '/home/projects/storm-damage/data/building_footprints/building_footprint_reprojected.shp'
shp_ds = ogr.Open(shp_file_path, 0)  # 0 means read-only

crs_utm_19N = 'EPSG:32619'
gdf_reprojected = shp.to_crs(crs_utm_19N)
# shp_layer = shp_ds.GetLayer()

# # Fetch the original SRS
# shp_srs = shp_layer.GetSpatialRef()

# # Print the original SRS WKT
# print("Original Shapefile WKT SRS:\n", shp_srs.ExportToWkt())

# # Target SRS from the GeoTIFF WKT
# target_srs = osr.SpatialReference()
# target_srs.ImportFromWkt(tif_srs)

# # Reproject the shapefile
# # For reprojection, we'll use a command-line call to ogr2ogr. This is an example to run outside Python.
# # Replace 'path/to/your/new_shapefile.shp' with the desired output path for the reprojected shapefile
# ogr2ogr_command = f'ogr2ogr -t_srs "{tif_srs}" "{new_shp_file_path}" "{shp_file_path}"'
# print("Run this command in your terminal:\n", ogr2ogr_command)

# %%
import rasterio
import geopandas as gpd
from shapely.geometry import box
from osgeo import gdal

# Assuming post_event_image and gdf_reprojected are defined as per your setup
post_event_image = '../data/raw/Post_Event_San_Juan.tif'

# Open the TIFF file to get its geotransform and CRS
with rasterio.open(post_event_image) as src:
    bounds = src.bounds
    crs = src.crs

# Define the size of your grid/tiles
grid_x, grid_y = 512, 512  # Example sizes
tile_x, tile_y = 73, 102  # Example tile position

# Calculate the bounds for the specified grid
minx = bounds.left + tile_x * grid_x * src.res[0]  # Adjusted for tile_x position
maxy = bounds.top - tile_y * grid_y * abs(src.res[1])  # Adjusted for tile_y position
miny = maxy - grid_y * abs(src.res[1])  # Adjusted for height of the tile
maxx = minx + grid_x * src.res[0]  # Adjusted for width of the tile

# Create a polygon for the specified tile
first_tile_polygon = box(minx, miny, maxx, maxy)

# Convert the polygon into a GeoDataFrame
first_tile_gdf = gpd.GeoDataFrame({'geometry': [first_tile_polygon]}, crs=crs)

# Ensure the building footprints are in the same CRS as the first_tile_gdf
building_footprints_gdf = gdf_reprojected.to_crs(first_tile_gdf.crs)

# Check if the specified tile intersects with any building footprint
intersects = building_footprints_gdf.intersects(first_tile_polygon)

# If any intersection occurs, this will be True
intersection_exists = intersects.any()

print(f"Does tile {tile_x, tile_y} intersect with any building footprint? {intersection_exists}")

# %%
print(gdf_reprojected.head())
print(shp.head())

# %%
import os
import geopandas as gpd
import rasterio
from shapely.geometry import Polygon, box
from osgeo import gdal, osr

def generate_tiles(input_file, output_dir, grid_x, grid_y, shp):
    # Open the source raster file
    with rasterio.open(input_file) as src:
        width, height = src.width, src.height
        crs = src.crs
        bounds = src.bounds
    
    building_footprints_gdf = shp.to_crs(crs)
    ds = gdal.Open(input_file)

    # Get image size and number of bands
    width = ds.RasterXSize
    height = ds.RasterYSize
    num_bands = ds.RasterCount

    # Calculate number of tiles in each dimension
    num_tiles_x = (width // grid_x)
    num_tiles_y = (height // grid_y)

    print(f"Total number of tiles: {num_tiles_x * num_tiles_y}")

    # Create output directory if not exists
    os.makedirs(output_dir, exist_ok=True)
    print('here')
    count = 0
    for i in range(num_tiles_x):
        for j in range(num_tiles_y):
            x_offset, y_offset = i * grid_x, j * grid_y
            minx = bounds.left + i * grid_x * src.res[0]  # Adjusted for tile_x position
            maxy = bounds.top - j * grid_y * abs(src.res[1])  # Adjusted for tile_y position
            miny = maxy - grid_y * abs(src.res[1])  # Adjusted for height of the tile
            maxx = minx + grid_x * src.res[0]  # Adjusted for width of the tile

            # Create a bounding box for the tile
            tile_bbox = box(minx, miny, maxx, maxy)
            tile_width = min(grid_x, width - x_offset)
            tile_height = min(grid_y, height - y_offset)
            # Check for intersection with building footprints
            intersects = building_footprints_gdf.intersects(tile_bbox).any()
            
            if intersects:
                count += 1
                print(f"Tile {i}, {j} intersects with building footprint(s).")

                # Read the tile data
                tile = []
                for band in range(1, num_bands + 1):
                    tile_data = ds.GetRasterBand(band).ReadAsArray(x_offset, y_offset, tile_width, tile_height)
                    tile.append(tile_data)
                # Save the tile using GDAL
                output_file = os.path.join(output_dir, f"tile_{i}_{j}.tif")
                driver = gdal.GetDriverByName('GTiff')
                options = ['COMPRESS=DEFLATE', 'PREDICTOR=2', 'TILED=YES']
                out_ds = driver.Create(output_file, tile_width, tile_height, num_bands, 
                       ds.GetRasterBand(1).DataType, options=options)
                
                
                geotransform = list(ds.GetGeoTransform())
                geotransform[0] = geotransform[0] + x_offset * geotransform[1]
                geotransform[3] = geotransform[3] + y_offset * geotransform[5]
                out_ds.SetGeoTransform(tuple(geotransform))

                # Set the projection
                out_ds.SetProjection(ds.GetProjection())

                # Write each band to the output file
                for band in range(1, num_bands + 1):
                    out_band = out_ds.GetRasterBand(band)
                    out_band.WriteArray(tile[band - 1])

                # Close the output file
                out_ds = None

# Example usage
# input_file = 'path_to_your_tiff.tif'
# output_dir = 'path_to_output_directory'
# grid_x, grid_y = 512, 512
# building_footprints_gdf = your_building_footprints_gdf_loaded_and_reprojected_if_necessary
# generate_tiles(input_file, output_dir, grid_x, grid_y, building_footprints_gdf)

# %%
input_file = "../data/raw/Post_Event_San_Juan.tif"
output_dir = "../data/intermediate/Post_Event_Grids_In_TIFF_all_buildings"
grid_x = 512
grid_y = 512
generate_tiles(input_file, output_dir, grid_x, grid_y, shp)
# Out:
# Total number of tiles: 10730
# here
# Tile 0, 11 intersects with building footprint(s).
# Tile 0, 12 intersects with building footprint(s).
# Tile 0, 13 intersects with building footprint(s).
# Tile 0, 14 intersects with building footprint(s).
# Tile 0, 19 intersects with building footprint(s).
# Tile 0, 20 intersects with building footprint(s).
# Tile 0, 21 intersects with building footprint(s).
# Tile 0, 22 intersects with building footprint(s).
# Tile 0, 23 intersects with building footprint(s).
# Tile 0, 24 intersects with building footprint(s).
# Tile 0, 26 intersects with building footprint(s).
# Tile 0, 27 intersects with building footprint(s).
# Tile 0, 28 intersects with building footprint(s).
# Tile 0, 29 intersects with building footprint(s).
# Tile 0, 30 intersects with building footprint(s).
# Tile 0, 31 intersects with building footprint(s).
# Tile 0, 32 intersects with building footprint(s).
# Tile 0, 33 intersects with building footprint(s).
# Tile 0, 35 intersects with building footprint(s).
# Tile 0, 36 intersects with building footprint(s).
# Tile 0, 39 intersects with building footprint(s).
# Tile 0, 40 intersects with building footprint(s).
# Tile 0, 43 intersects with building footprint(s).
# Tile 0, 44 intersects with building footprint(s).
# Tile 0, 45 intersects with building footprint(s).
# Tile 0, 46 intersects with building footprint(s).
# Tile 0, 48 intersects with building footprint(s).
# Tile 0, 49 intersects with building footprint(s).
# Tile 0, 50 intersects with building footprint(s).
# Tile 0, 51 intersects with building footprint(s).
# Tile 0, 52 intersects with building footprint(s).
# Tile 0, 53 intersects with building footprint(s).
# Tile 0, 54 intersects with building footprint(s).
# Tile 0, 55 intersects with building footprint(s).
# Tile 0, 56 intersects with building footprint(s).
# Tile 0, 57 intersects with building footprint(s).
# Tile 0, 58 intersects with building footprint(s).
# Tile 0, 59 intersects with building footprint(s).
# Tile 0, 60 intersects with building footprint(s).
# Tile 0, 61 intersects with building footprint(s).
# Tile 0, 62 intersects with building footprint(s).
# Tile 0, 63 intersects with building footprint(s).
# Tile 0, 64 intersects with building footprint(s).
# Tile 0, 65 intersects with building footprint(s).
# Tile 0, 66 intersects with building footprint(s).
# Tile 0, 67 intersects with building footprint(s).
# Tile 0, 68 intersects with building footprint(s).
# Tile 0, 69 intersects with building footprint(s).
# Tile 0, 70 intersects with building footprint(s).
# Tile 0, 71 intersects with building footprint(s).
# Tile 0, 72 intersects with building footprint(s).
# Tile 0, 73 intersects with building footprint(s).
# Tile 0, 74 intersects with building footprint(s).
# Tile 0, 75 intersects with building footprint(s).
# Tile 0, 76 intersects with building footprint(s).
# Tile 0, 77 intersects with building footprint(s).
# Tile 0, 78 intersects with building footprint(s).
# Tile 0, 79 intersects with building footprint(s).
# Tile 0, 80 intersects with building footprint(s).
# Tile 0, 81 intersects with building footprint(s).
# Tile 0, 82 intersects with building footprint(s).
# Tile 0, 83 intersects with building footprint(s).
# Tile 0, 84 intersects with building footprint(s).
# Tile 0, 85 intersects with building footprint(s).
# Tile 0, 86 intersects with building footprint(s).
# Tile 0, 87 intersects with building footprint(s).
# Tile 0, 88 intersects with building footprint(s).
# Tile 0, 89 intersects with building footprint(s).
# Tile 0, 90 intersects with building footprint(s).
# Tile 0, 91 intersects with building footprint(s).
# Tile 0, 92 intersects with building footprint(s).
# Tile 0, 93 intersects with building footprint(s).
# Tile 0, 94 intersects with building footprint(s).
# Tile 0, 95 intersects with building footprint(s).
# Tile 0, 96 intersects with building footprint(s).
# Tile 0, 97 intersects with building footprint(s).
# Tile 0, 98 intersects with building footprint(s).
# Tile 0, 99 intersects with building footprint(s).
# Tile 0, 100 intersects with building footprint(s).
# Tile 0, 101 intersects with building footprint(s).
# Tile 0, 102 intersects with building footprint(s).
# Tile 0, 103 intersects with building footprint(s).
# Tile 0, 104 intersects with building footprint(s).
# Tile 0, 105 intersects with building footprint(s).
# Tile 0, 106 intersects with building footprint(s).
# Tile 0, 107 intersects with building footprint(s).
# Tile 0, 108 intersects with building footprint(s).
# Tile 0, 109 intersects with building footprint(s).
# Tile 0, 110 intersects with building footprint(s).
# Tile 0, 111 intersects with building footprint(s).
# Tile 0, 112 intersects with building footprint(s).
# Tile 0, 114 intersects with building footprint(s).
# Tile 0, 115 intersects with building footprint(s).
# Tile 0, 116 intersects with building footprint(s).
# Tile 0, 117 intersects with building footprint(s).
# Tile 0, 118 intersects with building footprint(s).
# Tile 0, 119 intersects with building footprint(s).
# Tile 0, 120 intersects with building footprint(s).
# Tile 0, 121 intersects with building footprint(s).
# Tile 0, 122 intersects with building footprint(s).
# Tile 0, 123 intersects with building footprint(s).
# Tile 0, 124 intersects with building footprint(s).
# Tile 0, 127 intersects with building footprint(s).
# Tile 0, 128 intersects with building footprint(s).
# Tile 0, 129 intersects with building footprint(s).
# Tile 0, 130 intersects with building footprint(s).
# Tile 0, 131 intersects with building footprint(s).
# Tile 0, 132 intersects with building footprint(s).
# Tile 0, 133 intersects with building footprint(s).
# Tile 0, 138 intersects with building footprint(s).
# Tile 0, 141 intersects with building footprint(s).
# Tile 0, 142 intersects with building footprint(s).
# Tile 0, 143 intersects with building footprint(s).
# Tile 0, 144 intersects with building footprint(s).
# Tile 1, 10 intersects with building footprint(s).
# Tile 1, 11 intersects with building footprint(s).
# Tile 1, 12 intersects with building footprint(s).
# Tile 1, 13 intersects with building footprint(s).
# Tile 1, 14 intersects with building footprint(s).
# Tile 1, 15 intersects with building footprint(s).
# Tile 1, 16 intersects with building footprint(s).
# Tile 1, 17 intersects with building footprint(s).
# Tile 1, 19 intersects with building footprint(s).
# Tile 1, 20 intersects with building footprint(s).
# Tile 1, 21 intersects with building footprint(s).
# Tile 1, 22 intersects with building footprint(s).
# Tile 1, 23 intersects with building footprint(s).
# Tile 1, 24 intersects with building footprint(s).
# Tile 1, 25 intersects with building footprint(s).
# Tile 1, 26 intersects with building footprint(s).
# Tile 1, 27 intersects with building footprint(s).
# Tile 1, 28 intersects with building footprint(s).
# Tile 1, 29 intersects with building footprint(s).
# Tile 1, 30 intersects with building footprint(s).
# Tile 1, 31 intersects with building footprint(s).
# Tile 1, 32 intersects with building footprint(s).
# Tile 1, 33 intersects with building footprint(s).
# Tile 1, 34 intersects with building footprint(s).
# Tile 1, 35 intersects with building footprint(s).
# Tile 1, 36 intersects with building footprint(s).
# Tile 1, 37 intersects with building footprint(s).
# Tile 1, 39 intersects with building footprint(s).
# Tile 1, 40 intersects with building footprint(s).
# Tile 1, 44 intersects with building footprint(s).
# Tile 1, 45 intersects with building footprint(s).
# Tile 1, 46 intersects with building footprint(s).
# Tile 1, 48 intersects with building footprint(s).
# Tile 1, 49 intersects with building footprint(s).
# Tile 1, 50 intersects with building footprint(s).
# Tile 1, 52 intersects with building footprint(s).
# Tile 1, 53 intersects with building footprint(s).
# Tile 1, 54 intersects with building footprint(s).
# Tile 1, 55 intersects with building footprint(s).
# Tile 1, 56 intersects with building footprint(s).
# Tile 1, 57 intersects with building footprint(s).
# Tile 1, 58 intersects with building footprint(s).
# Tile 1, 59 intersects with building footprint(s).
# Tile 1, 60 intersects with building footprint(s).
# Tile 1, 61 intersects with building footprint(s).
# Tile 1, 62 intersects with building footprint(s).
# Tile 1, 63 intersects with building footprint(s).
# Tile 1, 64 intersects with building footprint(s).
# Tile 1, 65 intersects with building footprint(s).
# Tile 1, 66 intersects with building footprint(s).
# Tile 1, 67 intersects with building footprint(s).
# Tile 1, 68 intersects with building footprint(s).
# Tile 1, 69 intersects with building footprint(s).
# Tile 1, 70 intersects with building footprint(s).
# Tile 1, 71 intersects with building footprint(s).
# Tile 1, 72 intersects with building footprint(s).
# Tile 1, 73 intersects with building footprint(s).
# Tile 1, 74 intersects with building footprint(s).
# Tile 1, 75 intersects with building footprint(s).
# Tile 1, 76 intersects with building footprint(s).
# Tile 1, 77 intersects with building footprint(s).
# Tile 1, 78 intersects with building footprint(s).
# Tile 1, 79 intersects with building footprint(s).
# Tile 1, 80 intersects with building footprint(s).
# Tile 1, 81 intersects with building footprint(s).
# Tile 1, 82 intersects with building footprint(s).
# Tile 1, 83 intersects with building footprint(s).
# Tile 1, 84 intersects with building footprint(s).
# Tile 1, 85 intersects with building footprint(s).
# Tile 1, 86 intersects with building footprint(s).
# Tile 1, 87 intersects with building footprint(s).
# Tile 1, 88 intersects with building footprint(s).
# Tile 1, 89 intersects with building footprint(s).
# Tile 1, 90 intersects with building footprint(s).
# Tile 1, 91 intersects with building footprint(s).
# Tile 1, 92 intersects with building footprint(s).
# Tile 1, 93 intersects with building footprint(s).
# Tile 1, 94 intersects with building footprint(s).
# Tile 1, 95 intersects with building footprint(s).
# Tile 1, 96 intersects with building footprint(s).
# Tile 1, 97 intersects with building footprint(s).
# Tile 1, 98 intersects with building footprint(s).
# Tile 1, 99 intersects with building footprint(s).
# Tile 1, 100 intersects with building footprint(s).
# Tile 1, 101 intersects with building footprint(s).
# Tile 1, 102 intersects with building footprint(s).
# Tile 1, 103 intersects with building footprint(s).
# Tile 1, 104 intersects with building footprint(s).
# Tile 1, 105 intersects with building footprint(s).
# Tile 1, 106 intersects with building footprint(s).
# Tile 1, 107 intersects with building footprint(s).
# Tile 1, 108 intersects with building footprint(s).
# Tile 1, 109 intersects with building footprint(s).
# Tile 1, 110 intersects with building footprint(s).
# Tile 1, 111 intersects with building footprint(s).
# Tile 1, 112 intersects with building footprint(s).
# Tile 1, 113 intersects with building footprint(s).
# Tile 1, 114 intersects with building footprint(s).
# Tile 1, 115 intersects with building footprint(s).
# Tile 1, 116 intersects with building footprint(s).
# Tile 1, 118 intersects with building footprint(s).
# Tile 1, 119 intersects with building footprint(s).
# Tile 1, 122 intersects with building footprint(s).
# Tile 1, 123 intersects with building footprint(s).
# Tile 1, 124 intersects with building footprint(s).
# Tile 1, 131 intersects with building footprint(s).
# Tile 1, 132 intersects with building footprint(s).
# Tile 1, 133 intersects with building footprint(s).
# Tile 1, 134 intersects with building footprint(s).
# Tile 1, 136 intersects with building footprint(s).
# Tile 1, 137 intersects with building footprint(s).
# Tile 1, 140 intersects with building footprint(s).
# Tile 1, 141 intersects with building footprint(s).
# Tile 1, 142 intersects with building footprint(s).
# Tile 1, 143 intersects with building footprint(s).
# Tile 1, 144 intersects with building footprint(s).
# Tile 2, 7 intersects with building footprint(s).
# Tile 2, 8 intersects with building footprint(s).
# Tile 2, 9 intersects with building footprint(s).
# Tile 2, 12 intersects with building footprint(s).
# Tile 2, 13 intersects with building footprint(s).
# Tile 2, 14 intersects with building footprint(s).
# Tile 2, 15 intersects with building footprint(s).
# Tile 2, 16 intersects with building footprint(s).
# Tile 2, 17 intersects with building footprint(s).
# Tile 2, 18 intersects with building footprint(s).
# Tile 2, 19 intersects with building footprint(s).
# Tile 2, 20 intersects with building footprint(s).
# Tile 2, 21 intersects with building footprint(s).
# Tile 2, 22 intersects with building footprint(s).
# Tile 2, 23 intersects with building footprint(s).
# Tile 2, 24 intersects with building footprint(s).
# Tile 2, 25 intersects with building footprint(s).
# Tile 2, 26 intersects with building footprint(s).
# Tile 2, 27 intersects with building footprint(s).
# Tile 2, 28 intersects with building footprint(s).
# Tile 2, 29 intersects with building footprint(s).
# Tile 2, 30 intersects with building footprint(s).
# Tile 2, 31 intersects with building footprint(s).
# Tile 2, 32 intersects with building footprint(s).
# Tile 2, 33 intersects with building footprint(s).
# Tile 2, 34 intersects with building footprint(s).
# Tile 2, 35 intersects with building footprint(s).
# Tile 2, 36 intersects with building footprint(s).
# Tile 2, 37 intersects with building footprint(s).
# Tile 2, 38 intersects with building footprint(s).
# Tile 2, 39 intersects with building footprint(s).
# Tile 2, 40 intersects with building footprint(s).
# Tile 2, 42 intersects with building footprint(s).
# Tile 2, 43 intersects with building footprint(s).
# Tile 2, 44 intersects with building footprint(s).
# Tile 2, 45 intersects with building footprint(s).
# Tile 2, 46 intersects with building footprint(s).
# Tile 2, 48 intersects with building footprint(s).
# Tile 2, 49 intersects with building footprint(s).
# Tile 2, 50 intersects with building footprint(s).
# Tile 2, 51 intersects with building footprint(s).
# Tile 2, 52 intersects with building footprint(s).
# Tile 2, 53 intersects with building footprint(s).
# Tile 2, 54 intersects with building footprint(s).
# Tile 2, 55 intersects with building footprint(s).
# Tile 2, 56 intersects with building footprint(s).
# Tile 2, 57 intersects with building footprint(s).
# Tile 2, 58 intersects with building footprint(s).
# Tile 2, 59 intersects with building footprint(s).
# Tile 2, 60 intersects with building footprint(s).
# Tile 2, 61 intersects with building footprint(s).
# Tile 2, 62 intersects with building footprint(s).
# Tile 2, 63 intersects with building footprint(s).
# Tile 2, 64 intersects with building footprint(s).
# Tile 2, 65 intersects with building footprint(s).
# Tile 2, 66 intersects with building footprint(s).
# Tile 2, 67 intersects with building footprint(s).
# Tile 2, 68 intersects with building footprint(s).
# Tile 2, 69 intersects with building footprint(s).
# Tile 2, 70 intersects with building footprint(s).
# Tile 2, 71 intersects with building footprint(s).
# Tile 2, 72 intersects with building footprint(s).
# Tile 2, 73 intersects with building footprint(s).
# Tile 2, 74 intersects with building footprint(s).
# Tile 2, 75 intersects with building footprint(s).
# Tile 2, 76 intersects with building footprint(s).
# Tile 2, 77 intersects with building footprint(s).
# Tile 2, 78 intersects with building footprint(s).
# Tile 2, 79 intersects with building footprint(s).
# Tile 2, 80 intersects with building footprint(s).
# Tile 2, 81 intersects with building footprint(s).
# Tile 2, 82 intersects with building footprint(s).
# Tile 2, 83 intersects with building footprint(s).
# Tile 2, 84 intersects with building footprint(s).
# Tile 2, 85 intersects with building footprint(s).
# Tile 2, 86 intersects with building footprint(s).
# Tile 2, 87 intersects with building footprint(s).
# Tile 2, 88 intersects with building footprint(s).
# Tile 2, 89 intersects with building footprint(s).
# Tile 2, 90 intersects with building footprint(s).
# Tile 2, 91 intersects with building footprint(s).
# Tile 2, 92 intersects with building footprint(s).
# Tile 2, 93 intersects with building footprint(s).
# Tile 2, 94 intersects with building footprint(s).
# Tile 2, 95 intersects with building footprint(s).
# Tile 2, 96 intersects with building footprint(s).
# Tile 2, 97 intersects with building footprint(s).
# Tile 2, 98 intersects with building footprint(s).
# Tile 2, 99 intersects with building footprint(s).
# Tile 2, 100 intersects with building footprint(s).
# Tile 2, 101 intersects with building footprint(s).
# Tile 2, 102 intersects with building footprint(s).
# Tile 2, 103 intersects with building footprint(s).
# Tile 2, 104 intersects with building footprint(s).
# Tile 2, 105 intersects with building footprint(s).
# Tile 2, 106 intersects with building footprint(s).
# Tile 2, 107 intersects with building footprint(s).
# Tile 2, 108 intersects with building footprint(s).
# Tile 2, 109 intersects with building footprint(s).
# Tile 2, 111 intersects with building footprint(s).
# Tile 2, 116 intersects with building footprint(s).
# Tile 2, 118 intersects with building footprint(s).
# Tile 2, 119 intersects with building footprint(s).
# Tile 2, 121 intersects with building footprint(s).
# Tile 2, 122 intersects with building footprint(s).
# Tile 2, 123 intersects with building footprint(s).
# Tile 2, 124 intersects with building footprint(s).
# Tile 2, 125 intersects with building footprint(s).
# Tile 2, 126 intersects with building footprint(s).
# Tile 2, 127 intersects with building footprint(s).
# Tile 2, 131 intersects with building footprint(s).
# Tile 2, 132 intersects with building footprint(s).
# Tile 2, 133 intersects with building footprint(s).
# Tile 2, 134 intersects with building footprint(s).
# Tile 2, 137 intersects with building footprint(s).
# Tile 2, 138 intersects with building footprint(s).
# Tile 2, 141 intersects with building footprint(s).
# Tile 2, 142 intersects with building footprint(s).
# Tile 2, 143 intersects with building footprint(s).
# Tile 2, 144 intersects with building footprint(s).
# Tile 3, 3 intersects with building footprint(s).
# Tile 3, 4 intersects with building footprint(s).
# Tile 3, 5 intersects with building footprint(s).
# Tile 3, 6 intersects with building footprint(s).
# Tile 3, 13 intersects with building footprint(s).
# Tile 3, 14 intersects with building footprint(s).
# Tile 3, 15 intersects with building footprint(s).
# Tile 3, 16 intersects with building footprint(s).
# Tile 3, 17 intersects with building footprint(s).
# Tile 3, 18 intersects with building footprint(s).
# Tile 3, 19 intersects with building footprint(s).
# Tile 3, 20 intersects with building footprint(s).
# Tile 3, 21 intersects with building footprint(s).
# Tile 3, 22 intersects with building footprint(s).
# Tile 3, 23 intersects with building footprint(s).
# Tile 3, 24 intersects with building footprint(s).
# Tile 3, 25 intersects with building footprint(s).
# Tile 3, 26 intersects with building footprint(s).
# Tile 3, 27 intersects with building footprint(s).
# Tile 3, 28 intersects with building footprint(s).
# Tile 3, 29 intersects with building footprint(s).
# Tile 3, 30 intersects with building footprint(s).
# Tile 3, 31 intersects with building footprint(s).
# Tile 3, 32 intersects with building footprint(s).
# Tile 3, 33 intersects with building footprint(s).
# Tile 3, 34 intersects with building footprint(s).
# Tile 3, 35 intersects with building footprint(s).
# Tile 3, 36 intersects with building footprint(s).
# Tile 3, 37 intersects with building footprint(s).
# Tile 3, 38 intersects with building footprint(s).
# Tile 3, 41 intersects with building footprint(s).
# Tile 3, 42 intersects with building footprint(s).
# Tile 3, 43 intersects with building footprint(s).
# Tile 3, 44 intersects with building footprint(s).
# Tile 3, 45 intersects with building footprint(s).
# Tile 3, 46 intersects with building footprint(s).
# Tile 3, 47 intersects with building footprint(s).
# Tile 3, 48 intersects with building footprint(s).
# Tile 3, 49 intersects with building footprint(s).
# Tile 3, 50 intersects with building footprint(s).
# Tile 3, 51 intersects with building footprint(s).
# Tile 3, 52 intersects with building footprint(s).
# Tile 3, 53 intersects with building footprint(s).
# Tile 3, 54 intersects with building footprint(s).
# Tile 3, 55 intersects with building footprint(s).
# Tile 3, 56 intersects with building footprint(s).
# Tile 3, 57 intersects with building footprint(s).
# Tile 3, 58 intersects with building footprint(s).
# Tile 3, 59 intersects with building footprint(s).
# Tile 3, 60 intersects with building footprint(s).
# Tile 3, 61 intersects with building footprint(s).
# Tile 3, 62 intersects with building footprint(s).
# Tile 3, 63 intersects with building footprint(s).
# Tile 3, 64 intersects with building footprint(s).
# Tile 3, 65 intersects with building footprint(s).
# Tile 3, 66 intersects with building footprint(s).
# Tile 3, 67 intersects with building footprint(s).
# Tile 3, 68 intersects with building footprint(s).
# Tile 3, 69 intersects with building footprint(s).
# Tile 3, 70 intersects with building footprint(s).
# Tile 3, 71 intersects with building footprint(s).
# Tile 3, 72 intersects with building footprint(s).
# Tile 3, 73 intersects with building footprint(s).
# Tile 3, 74 intersects with building footprint(s).
# Tile 3, 75 intersects with building footprint(s).
# Tile 3, 76 intersects with building footprint(s).
# Tile 3, 77 intersects with building footprint(s).
# Tile 3, 78 intersects with building footprint(s).
# Tile 3, 79 intersects with building footprint(s).
# Tile 3, 80 intersects with building footprint(s).
# Tile 3, 81 intersects with building footprint(s).
# Tile 3, 82 intersects with building footprint(s).
# Tile 3, 83 intersects with building footprint(s).
# Tile 3, 84 intersects with building footprint(s).
# Tile 3, 85 intersects with building footprint(s).
# Tile 3, 86 intersects with building footprint(s).
# Tile 3, 88 intersects with building footprint(s).
# Tile 3, 89 intersects with building footprint(s).
# Tile 3, 90 intersects with building footprint(s).
# Tile 3, 91 intersects with building footprint(s).
# Tile 3, 92 intersects with building footprint(s).
# Tile 3, 93 intersects with building footprint(s).
# Tile 3, 94 intersects with building footprint(s).
# Tile 3, 95 intersects with building footprint(s).
# Tile 3, 96 intersects with building footprint(s).
# Tile 3, 97 intersects with building footprint(s).
# Tile 3, 98 intersects with building footprint(s).
# Tile 3, 99 intersects with building footprint(s).
# Tile 3, 100 intersects with building footprint(s).
# Tile 3, 101 intersects with building footprint(s).
# Tile 3, 102 intersects with building footprint(s).
# Tile 3, 103 intersects with building footprint(s).
# Tile 3, 104 intersects with building footprint(s).
# Tile 3, 105 intersects with building footprint(s).
# Tile 3, 106 intersects with building footprint(s).
# Tile 3, 107 intersects with building footprint(s).
# Tile 3, 108 intersects with building footprint(s).
# Tile 3, 109 intersects with building footprint(s).
# Tile 3, 111 intersects with building footprint(s).
# Tile 3, 112 intersects with building footprint(s).
# Tile 3, 113 intersects with building footprint(s).
# Tile 3, 115 intersects with building footprint(s).
# Tile 3, 118 intersects with building footprint(s).
# Tile 3, 119 intersects with building footprint(s).
# Tile 3, 121 intersects with building footprint(s).
# Tile 3, 122 intersects with building footprint(s).
# Tile 3, 123 intersects with building footprint(s).
# Tile 3, 124 intersects with building footprint(s).
# Tile 3, 125 intersects with building footprint(s).
# Tile 3, 126 intersects with building footprint(s).
# Tile 3, 127 intersects with building footprint(s).
# Tile 3, 128 intersects with building footprint(s).
# Tile 3, 129 intersects with building footprint(s).
# Tile 3, 130 intersects with building footprint(s).
# Tile 3, 131 intersects with building footprint(s).
# Tile 3, 132 intersects with building footprint(s).
# Tile 3, 136 intersects with building footprint(s).
# Tile 3, 139 intersects with building footprint(s).
# Tile 3, 140 intersects with building footprint(s).
# Tile 3, 141 intersects with building footprint(s).
# Tile 3, 142 intersects with building footprint(s).
# Tile 3, 143 intersects with building footprint(s).
# Tile 3, 144 intersects with building footprint(s).
# Tile 4, 3 intersects with building footprint(s).
# Tile 4, 4 intersects with building footprint(s).
# Tile 4, 5 intersects with building footprint(s).
# Tile 4, 14 intersects with building footprint(s).
# Tile 4, 15 intersects with building footprint(s).
# Tile 4, 16 intersects with building footprint(s).
# Tile 4, 17 intersects with building footprint(s).
# Tile 4, 18 intersects with building footprint(s).
# Tile 4, 19 intersects with building footprint(s).
# Tile 4, 20 intersects with building footprint(s).
# Tile 4, 21 intersects with building footprint(s).
# Tile 4, 22 intersects with building footprint(s).
# Tile 4, 23 intersects with building footprint(s).
# Tile 4, 24 intersects with building footprint(s).
# Tile 4, 25 intersects with building footprint(s).
# Tile 4, 26 intersects with building footprint(s).
# Tile 4, 27 intersects with building footprint(s).
# Tile 4, 28 intersects with building footprint(s).
# Tile 4, 29 intersects with building footprint(s).
# Tile 4, 30 intersects with building footprint(s).
# Tile 4, 31 intersects with building footprint(s).
# Tile 4, 32 intersects with building footprint(s).
# Tile 4, 33 intersects with building footprint(s).
# Tile 4, 34 intersects with building footprint(s).
# Tile 4, 35 intersects with building footprint(s).
# Tile 4, 36 intersects with building footprint(s).
# Tile 4, 37 intersects with building footprint(s).
# Tile 4, 38 intersects with building footprint(s).
# Tile 4, 39 intersects with building footprint(s).
# Tile 4, 40 intersects with building footprint(s).
# Tile 4, 41 intersects with building footprint(s).
# Tile 4, 42 intersects with building footprint(s).
# Tile 4, 43 intersects with building footprint(s).
# Tile 4, 44 intersects with building footprint(s).
# Tile 4, 45 intersects with building footprint(s).
# Tile 4, 46 intersects with building footprint(s).
# Tile 4, 47 intersects with building footprint(s).
# Tile 4, 48 intersects with building footprint(s).
# Tile 4, 49 intersects with building footprint(s).
# Tile 4, 50 intersects with building footprint(s).
# Tile 4, 51 intersects with building footprint(s).
# Tile 4, 52 intersects with building footprint(s).
# Tile 4, 53 intersects with building footprint(s).
# Tile 4, 54 intersects with building footprint(s).
# Tile 4, 56 intersects with building footprint(s).
# Tile 4, 57 intersects with building footprint(s).
# Tile 4, 58 intersects with building footprint(s).
# Tile 4, 59 intersects with building footprint(s).
# Tile 4, 60 intersects with building footprint(s).
# Tile 4, 61 intersects with building footprint(s).
# Tile 4, 62 intersects with building footprint(s).
# Tile 4, 63 intersects with building footprint(s).
# Tile 4, 64 intersects with building footprint(s).
# Tile 4, 65 intersects with building footprint(s).
# Tile 4, 66 intersects with building footprint(s).
# Tile 4, 67 intersects with building footprint(s).
# Tile 4, 68 intersects with building footprint(s).
# Tile 4, 69 intersects with building footprint(s).
# Tile 4, 70 intersects with building footprint(s).
# Tile 4, 71 intersects with building footprint(s).
# Tile 4, 72 intersects with building footprint(s).
# Tile 4, 73 intersects with building footprint(s).
# Tile 4, 74 intersects with building footprint(s).
# Tile 4, 75 intersects with building footprint(s).
# Tile 4, 76 intersects with building footprint(s).
# Tile 4, 77 intersects with building footprint(s).
# Tile 4, 78 intersects with building footprint(s).
# Tile 4, 79 intersects with building footprint(s).
# Tile 4, 80 intersects with building footprint(s).
# Tile 4, 81 intersects with building footprint(s).
# Tile 4, 82 intersects with building footprint(s).
# Tile 4, 83 intersects with building footprint(s).
# Tile 4, 84 intersects with building footprint(s).
# Tile 4, 85 intersects with building footprint(s).
# Tile 4, 86 intersects with building footprint(s).
# Tile 4, 87 intersects with building footprint(s).
# Tile 4, 88 intersects with building footprint(s).
# Tile 4, 89 intersects with building footprint(s).
# Tile 4, 90 intersects with building footprint(s).
# Tile 4, 91 intersects with building footprint(s).
# Tile 4, 92 intersects with building footprint(s).
# Tile 4, 93 intersects with building footprint(s).
# Tile 4, 94 intersects with building footprint(s).
# Tile 4, 95 intersects with building footprint(s).
# Tile 4, 96 intersects with building footprint(s).
# Tile 4, 97 intersects with building footprint(s).
# Tile 4, 98 intersects with building footprint(s).
# Tile 4, 100 intersects with building footprint(s).
# Tile 4, 101 intersects with building footprint(s).
# Tile 4, 102 intersects with building footprint(s).
# Tile 4, 103 intersects with building footprint(s).
# Tile 4, 104 intersects with building footprint(s).
# Tile 4, 105 intersects with building footprint(s).
# Tile 4, 106 intersects with building footprint(s).
# Tile 4, 107 intersects with building footprint(s).
# Tile 4, 108 intersects with building footprint(s).
# Tile 4, 109 intersects with building footprint(s).
# Tile 4, 110 intersects with building footprint(s).
# Tile 4, 111 intersects with building footprint(s).
# Tile 4, 112 intersects with building footprint(s).
# Tile 4, 113 intersects with building footprint(s).
# Tile 4, 114 intersects with building footprint(s).
# Tile 4, 115 intersects with building footprint(s).
# Tile 4, 116 intersects with building footprint(s).
# Tile 4, 118 intersects with building footprint(s).
# Tile 4, 122 intersects with building footprint(s).
# Tile 4, 123 intersects with building footprint(s).
# Tile 4, 124 intersects with building footprint(s).
# Tile 4, 125 intersects with building footprint(s).
# Tile 4, 126 intersects with building footprint(s).
# Tile 4, 127 intersects with building footprint(s).
# Tile 4, 128 intersects with building footprint(s).
# Tile 4, 129 intersects with building footprint(s).
# Tile 4, 130 intersects with building footprint(s).
# Tile 4, 131 intersects with building footprint(s).
# Tile 4, 133 intersects with building footprint(s).
# Tile 4, 134 intersects with building footprint(s).
# Tile 4, 135 intersects with building footprint(s).
# Tile 4, 136 intersects with building footprint(s).
# Tile 4, 139 intersects with building footprint(s).
# Tile 4, 140 intersects with building footprint(s).
# Tile 4, 141 intersects with building footprint(s).
# Tile 4, 142 intersects with building footprint(s).
# Tile 4, 143 intersects with building footprint(s).
# Tile 4, 144 intersects with building footprint(s).
# Tile 5, 3 intersects with building footprint(s).
# Tile 5, 15 intersects with building footprint(s).
# Tile 5, 16 intersects with building footprint(s).
# Tile 5, 17 intersects with building footprint(s).
# Tile 5, 18 intersects with building footprint(s).
# Tile 5, 19 intersects with building footprint(s).
# Tile 5, 20 intersects with building footprint(s).
# Tile 5, 21 intersects with building footprint(s).
# Tile 5, 22 intersects with building footprint(s).
# Tile 5, 23 intersects with building footprint(s).
# Tile 5, 24 intersects with building footprint(s).
# Tile 5, 25 intersects with building footprint(s).
# Tile 5, 26 intersects with building footprint(s).
# Tile 5, 27 intersects with building footprint(s).
# Tile 5, 28 intersects with building footprint(s).
# Tile 5, 29 intersects with building footprint(s).
# Tile 5, 30 intersects with building footprint(s).
# Tile 5, 31 intersects with building footprint(s).
# Tile 5, 32 intersects with building footprint(s).
# Tile 5, 33 intersects with building footprint(s).
# Tile 5, 34 intersects with building footprint(s).
# Tile 5, 35 intersects with building footprint(s).
# Tile 5, 36 intersects with building footprint(s).
# Tile 5, 37 intersects with building footprint(s).
# Tile 5, 38 intersects with building footprint(s).
# Tile 5, 39 intersects with building footprint(s).
# Tile 5, 40 intersects with building footprint(s).
# Tile 5, 41 intersects with building footprint(s).
# Tile 5, 43 intersects with building footprint(s).
# Tile 5, 44 intersects with building footprint(s).
# Tile 5, 45 intersects with building footprint(s).
# Tile 5, 46 intersects with building footprint(s).
# Tile 5, 47 intersects with building footprint(s).
# Tile 5, 48 intersects with building footprint(s).
# Tile 5, 49 intersects with building footprint(s).
# Tile 5, 50 intersects with building footprint(s).
# Tile 5, 51 intersects with building footprint(s).
# Tile 5, 52 intersects with building footprint(s).
# Tile 5, 53 intersects with building footprint(s).
# Tile 5, 54 intersects with building footprint(s).
# Tile 5, 55 intersects with building footprint(s).
# Tile 5, 56 intersects with building footprint(s).
# Tile 5, 57 intersects with building footprint(s).
# Tile 5, 58 intersects with building footprint(s).
# Tile 5, 59 intersects with building footprint(s).
# Tile 5, 60 intersects with building footprint(s).
# Tile 5, 61 intersects with building footprint(s).
# Tile 5, 62 intersects with building footprint(s).
# Tile 5, 63 intersects with building footprint(s).
# Tile 5, 64 intersects with building footprint(s).
# Tile 5, 65 intersects with building footprint(s).
# Tile 5, 66 intersects with building footprint(s).
# Tile 5, 67 intersects with building footprint(s).
# Tile 5, 68 intersects with building footprint(s).
# Tile 5, 69 intersects with building footprint(s).
# Tile 5, 70 intersects with building footprint(s).
# Tile 5, 71 intersects with building footprint(s).
# Tile 5, 72 intersects with building footprint(s).
# Tile 5, 73 intersects with building footprint(s).
# Tile 5, 74 intersects with building footprint(s).
# Tile 5, 75 intersects with building footprint(s).
# Tile 5, 76 intersects with building footprint(s).
# Tile 5, 77 intersects with building footprint(s).
# Tile 5, 78 intersects with building footprint(s).
# Tile 5, 79 intersects with building footprint(s).
# Tile 5, 80 intersects with building footprint(s).
# Tile 5, 81 intersects with building footprint(s).
# Tile 5, 82 intersects with building footprint(s).
# Tile 5, 83 intersects with building footprint(s).
# Tile 5, 84 intersects with building footprint(s).
# Tile 5, 85 intersects with building footprint(s).
# Tile 5, 86 intersects with building footprint(s).
# Tile 5, 87 intersects with building footprint(s).
# Tile 5, 88 intersects with building footprint(s).
# Tile 5, 89 intersects with building footprint(s).
# Tile 5, 90 intersects with building footprint(s).
# Tile 5, 91 intersects with building footprint(s).
# Tile 5, 92 intersects with building footprint(s).
# Tile 5, 93 intersects with building footprint(s).
# Tile 5, 94 intersects with building footprint(s).
# Tile 5, 95 intersects with building footprint(s).
# Tile 5, 96 intersects with building footprint(s).
# Tile 5, 97 intersects with building footprint(s).
# Tile 5, 98 intersects with building footprint(s).
# Tile 5, 101 intersects with building footprint(s).
# Tile 5, 102 intersects with building footprint(s).
# Tile 5, 103 intersects with building footprint(s).
# Tile 5, 104 intersects with building footprint(s).
# Tile 5, 105 intersects with building footprint(s).
# Tile 5, 106 intersects with building footprint(s).
# Tile 5, 107 intersects with building footprint(s).
# Tile 5, 108 intersects with building footprint(s).
# Tile 5, 109 intersects with building footprint(s).
# Tile 5, 110 intersects with building footprint(s).
# Tile 5, 111 intersects with building footprint(s).
# Tile 5, 112 intersects with building footprint(s).
# Tile 5, 113 intersects with building footprint(s).
# Tile 5, 114 intersects with building footprint(s).
# Tile 5, 115 intersects with building footprint(s).
# Tile 5, 116 intersects with building footprint(s).
# Tile 5, 117 intersects with building footprint(s).
# Tile 5, 118 intersects with building footprint(s).
# Tile 5, 119 intersects with building footprint(s).
# Tile 5, 122 intersects with building footprint(s).
# Tile 5, 123 intersects with building footprint(s).
# Tile 5, 124 intersects with building footprint(s).
# Tile 5, 125 intersects with building footprint(s).
# Tile 5, 126 intersects with building footprint(s).
# Tile 5, 127 intersects with building footprint(s).
# Tile 5, 128 intersects with building footprint(s).
# Tile 5, 129 intersects with building footprint(s).
# Tile 5, 139 intersects with building footprint(s).
# Tile 5, 140 intersects with building footprint(s).
# Tile 5, 141 intersects with building footprint(s).
# Tile 5, 142 intersects with building footprint(s).
# Tile 5, 143 intersects with building footprint(s).
# Tile 5, 144 intersects with building footprint(s).
# Tile 6, 4 intersects with building footprint(s).
# Tile 6, 16 intersects with building footprint(s).
# Tile 6, 17 intersects with building footprint(s).
# Tile 6, 18 intersects with building footprint(s).
# Tile 6, 19 intersects with building footprint(s).
# Tile 6, 20 intersects with building footprint(s).
# Tile 6, 21 intersects with building footprint(s).
# Tile 6, 22 intersects with building footprint(s).
# Tile 6, 23 intersects with building footprint(s).
# Tile 6, 24 intersects with building footprint(s).
# Tile 6, 25 intersects with building footprint(s).
# Tile 6, 26 intersects with building footprint(s).
# Tile 6, 27 intersects with building footprint(s).
# Tile 6, 28 intersects with building footprint(s).
# Tile 6, 29 intersects with building footprint(s).
# Tile 6, 30 intersects with building footprint(s).
# Tile 6, 31 intersects with building footprint(s).
# Tile 6, 32 intersects with building footprint(s).
# Tile 6, 33 intersects with building footprint(s).
# Tile 6, 34 intersects with building footprint(s).
# Tile 6, 35 intersects with building footprint(s).
# Tile 6, 36 intersects with building footprint(s).
# Tile 6, 37 intersects with building footprint(s).
# Tile 6, 38 intersects with building footprint(s).
# Tile 6, 39 intersects with building footprint(s).
# Tile 6, 40 intersects with building footprint(s).
# Tile 6, 43 intersects with building footprint(s).
# Tile 6, 44 intersects with building footprint(s).
# Tile 6, 45 intersects with building footprint(s).
# Tile 6, 46 intersects with building footprint(s).
# Tile 6, 47 intersects with building footprint(s).
# Tile 6, 48 intersects with building footprint(s).
# Tile 6, 49 intersects with building footprint(s).
# Tile 6, 50 intersects with building footprint(s).
# Tile 6, 51 intersects with building footprint(s).
# Tile 6, 52 intersects with building footprint(s).
# Tile 6, 53 intersects with building footprint(s).
# Tile 6, 54 intersects with building footprint(s).
# Tile 6, 55 intersects with building footprint(s).
# Tile 6, 56 intersects with building footprint(s).
# Tile 6, 57 intersects with building footprint(s).
# Tile 6, 58 intersects with building footprint(s).
# Tile 6, 59 intersects with building footprint(s).
# Tile 6, 60 intersects with building footprint(s).
# Tile 6, 61 intersects with building footprint(s).
# Tile 6, 62 intersects with building footprint(s).
# Tile 6, 63 intersects with building footprint(s).
# Tile 6, 64 intersects with building footprint(s).
# Tile 6, 65 intersects with building footprint(s).
# Tile 6, 66 intersects with building footprint(s).
# Tile 6, 67 intersects with building footprint(s).
# Tile 6, 68 intersects with building footprint(s).
# Tile 6, 69 intersects with building footprint(s).
# Tile 6, 70 intersects with building footprint(s).
# Tile 6, 71 intersects with building footprint(s).
# Tile 6, 72 intersects with building footprint(s).
# Tile 6, 73 intersects with building footprint(s).
# Tile 6, 74 intersects with building footprint(s).
# Tile 6, 75 intersects with building footprint(s).
# Tile 6, 76 intersects with building footprint(s).
# Tile 6, 77 intersects with building footprint(s).
# Tile 6, 78 intersects with building footprint(s).
# Tile 6, 79 intersects with building footprint(s).
# Tile 6, 80 intersects with building footprint(s).
# Tile 6, 81 intersects with building footprint(s).
# Tile 6, 82 intersects with building footprint(s).
# Tile 6, 83 intersects with building footprint(s).
# Tile 6, 84 intersects with building footprint(s).
# Tile 6, 85 intersects with building footprint(s).
# Tile 6, 86 intersects with building footprint(s).
# Tile 6, 87 intersects with building footprint(s).
# Tile 6, 88 intersects with building footprint(s).
# Tile 6, 89 intersects with building footprint(s).
# Tile 6, 90 intersects with building footprint(s).
# Tile 6, 91 intersects with building footprint(s).
# Tile 6, 92 intersects with building footprint(s).
# Tile 6, 93 intersects with building footprint(s).
# Tile 6, 94 intersects with building footprint(s).
# Tile 6, 95 intersects with building footprint(s).
# Tile 6, 96 intersects with building footprint(s).
# Tile 6, 97 intersects with building footprint(s).
# Tile 6, 98 intersects with building footprint(s).
# Tile 6, 99 intersects with building footprint(s).
# Tile 6, 100 intersects with building footprint(s).
# Tile 6, 101 intersects with building footprint(s).
# Tile 6, 102 intersects with building footprint(s).
# Tile 6, 104 intersects with building footprint(s).
# Tile 6, 105 intersects with building footprint(s).
# Tile 6, 106 intersects with building footprint(s).
# Tile 6, 107 intersects with building footprint(s).
# Tile 6, 108 intersects with building footprint(s).
# Tile 6, 109 intersects with building footprint(s).
# Tile 6, 110 intersects with building footprint(s).
# Tile 6, 111 intersects with building footprint(s).
# Tile 6, 112 intersects with building footprint(s).
# Tile 6, 113 intersects with building footprint(s).
# Tile 6, 114 intersects with building footprint(s).
# Tile 6, 115 intersects with building footprint(s).
# Tile 6, 119 intersects with building footprint(s).
# Tile 6, 120 intersects with building footprint(s).
# Tile 6, 121 intersects with building footprint(s).
# Tile 6, 122 intersects with building footprint(s).
# Tile 6, 123 intersects with building footprint(s).
# Tile 6, 124 intersects with building footprint(s).
# Tile 6, 125 intersects with building footprint(s).
# Tile 6, 126 intersects with building footprint(s).
# Tile 6, 127 intersects with building footprint(s).
# Tile 6, 128 intersects with building footprint(s).
# Tile 6, 129 intersects with building footprint(s).
# Tile 6, 131 intersects with building footprint(s).
# Tile 6, 132 intersects with building footprint(s).
# Tile 6, 140 intersects with building footprint(s).
# Tile 6, 141 intersects with building footprint(s).
# Tile 6, 142 intersects with building footprint(s).
# Tile 6, 143 intersects with building footprint(s).
# Tile 6, 144 intersects with building footprint(s).
# Tile 7, 3 intersects with building footprint(s).
# Tile 7, 4 intersects with building footprint(s).
# Tile 7, 17 intersects with building footprint(s).
# Tile 7, 18 intersects with building footprint(s).
# Tile 7, 19 intersects with building footprint(s).
# Tile 7, 20 intersects with building footprint(s).
# Tile 7, 21 intersects with building footprint(s).
# Tile 7, 22 intersects with building footprint(s).
# Tile 7, 23 intersects with building footprint(s).
# Tile 7, 24 intersects with building footprint(s).
# Tile 7, 25 intersects with building footprint(s).
# Tile 7, 26 intersects with building footprint(s).
# Tile 7, 27 intersects with building footprint(s).
# Tile 7, 28 intersects with building footprint(s).
# Tile 7, 29 intersects with building footprint(s).
# Tile 7, 30 intersects with building footprint(s).
# Tile 7, 31 intersects with building footprint(s).
# Tile 7, 32 intersects with building footprint(s).
# Tile 7, 33 intersects with building footprint(s).
# Tile 7, 34 intersects with building footprint(s).
# Tile 7, 35 intersects with building footprint(s).
# Tile 7, 36 intersects with building footprint(s).
# Tile 7, 37 intersects with building footprint(s).
# Tile 7, 38 intersects with building footprint(s).
# Tile 7, 39 intersects with building footprint(s).
# Tile 7, 42 intersects with building footprint(s).
# Tile 7, 43 intersects with building footprint(s).
# Tile 7, 44 intersects with building footprint(s).
# Tile 7, 45 intersects with building footprint(s).
# Tile 7, 46 intersects with building footprint(s).
# Tile 7, 47 intersects with building footprint(s).
# Tile 7, 48 intersects with building footprint(s).
# Tile 7, 49 intersects with building footprint(s).
# Tile 7, 50 intersects with building footprint(s).
# Tile 7, 51 intersects with building footprint(s).
# Tile 7, 52 intersects with building footprint(s).
# Tile 7, 53 intersects with building footprint(s).
# Tile 7, 54 intersects with building footprint(s).
# Tile 7, 55 intersects with building footprint(s).
# Tile 7, 56 intersects with building footprint(s).
# Tile 7, 57 intersects with building footprint(s).
# Tile 7, 58 intersects with building footprint(s).
# Tile 7, 59 intersects with building footprint(s).
# Tile 7, 60 intersects with building footprint(s).
# Tile 7, 61 intersects with building footprint(s).
# Tile 7, 62 intersects with building footprint(s).
# Tile 7, 63 intersects with building footprint(s).
# Tile 7, 64 intersects with building footprint(s).
# Tile 7, 65 intersects with building footprint(s).
# Tile 7, 66 intersects with building footprint(s).
# Tile 7, 67 intersects with building footprint(s).
# Tile 7, 68 intersects with building footprint(s).
# Tile 7, 69 intersects with building footprint(s).
# Tile 7, 70 intersects with building footprint(s).
# Tile 7, 71 intersects with building footprint(s).
# Tile 7, 72 intersects with building footprint(s).
# Tile 7, 73 intersects with building footprint(s).
# Tile 7, 74 intersects with building footprint(s).
# Tile 7, 75 intersects with building footprint(s).
# Tile 7, 76 intersects with building footprint(s).
# Tile 7, 77 intersects with building footprint(s).
# Tile 7, 78 intersects with building footprint(s).
# Tile 7, 79 intersects with building footprint(s).
# Tile 7, 80 intersects with building footprint(s).
# Tile 7, 81 intersects with building footprint(s).
# Tile 7, 82 intersects with building footprint(s).
# Tile 7, 83 intersects with building footprint(s).
# Tile 7, 84 intersects with building footprint(s).
# Tile 7, 86 intersects with building footprint(s).
# Tile 7, 87 intersects with building footprint(s).
# Tile 7, 88 intersects with building footprint(s).
# Tile 7, 89 intersects with building footprint(s).
# Tile 7, 90 intersects with building footprint(s).
# Tile 7, 91 intersects with building footprint(s).
# Tile 7, 92 intersects with building footprint(s).
# Tile 7, 93 intersects with building footprint(s).
# Tile 7, 94 intersects with building footprint(s).
# Tile 7, 95 intersects with building footprint(s).
# Tile 7, 96 intersects with building footprint(s).
# Tile 7, 97 intersects with building footprint(s).
# Tile 7, 98 intersects with building footprint(s).
# Tile 7, 99 intersects with building footprint(s).
# Tile 7, 100 intersects with building footprint(s).
# Tile 7, 101 intersects with building footprint(s).
# Tile 7, 102 intersects with building footprint(s).
# Tile 7, 103 intersects with building footprint(s).
# Tile 7, 104 intersects with building footprint(s).
# Tile 7, 105 intersects with building footprint(s).
# Tile 7, 106 intersects with building footprint(s).
# Tile 7, 107 intersects with building footprint(s).
# Tile 7, 108 intersects with building footprint(s).
# Tile 7, 109 intersects with building footprint(s).
# Tile 7, 110 intersects with building footprint(s).
# Tile 7, 111 intersects with building footprint(s).
# Tile 7, 112 intersects with building footprint(s).
# Tile 7, 113 intersects with building footprint(s).
# Tile 7, 114 intersects with building footprint(s).
# Tile 7, 116 intersects with building footprint(s).
# Tile 7, 117 intersects with building footprint(s).
# Tile 7, 118 intersects with building footprint(s).
# Tile 7, 119 intersects with building footprint(s).
# Tile 7, 120 intersects with building footprint(s).
# Tile 7, 121 intersects with building footprint(s).
# Tile 7, 122 intersects with building footprint(s).
# Tile 7, 123 intersects with building footprint(s).
# Tile 7, 124 intersects with building footprint(s).
# Tile 7, 125 intersects with building footprint(s).
# Tile 7, 126 intersects with building footprint(s).
# Tile 7, 127 intersects with building footprint(s).
# Tile 7, 128 intersects with building footprint(s).
# Tile 7, 132 intersects with building footprint(s).
# Tile 7, 139 intersects with building footprint(s).
# Tile 7, 140 intersects with building footprint(s).
# Tile 7, 142 intersects with building footprint(s).
# Tile 8, 18 intersects with building footprint(s).
# Tile 8, 19 intersects with building footprint(s).
# Tile 8, 20 intersects with building footprint(s).
# Tile 8, 21 intersects with building footprint(s).
# Tile 8, 22 intersects with building footprint(s).
# Tile 8, 23 intersects with building footprint(s).
# Tile 8, 24 intersects with building footprint(s).
# Tile 8, 25 intersects with building footprint(s).
# Tile 8, 26 intersects with building footprint(s).
# ...
# Tile 71, 44 intersects with building footprint(s).
# Tile 71, 45 intersects with building footprint(s).
# Tile 71, 46 intersects with building footprint(s).
# Tile 71, 47 intersects with building footprint(s).
# Tile 71, 48 intersects with building footprint(s).
# Tile 71, 49 intersects with building footprint(s).
# Tile 71, 50 intersects with building footprint(s).
# Tile 71, 51 intersects with building footprint(s).
# Tile 71, 52 intersects with building footprint(s).
# Tile 71, 53 intersects with building footprint(s).
# Tile 71, 54 intersects with building footprint(s).
# Tile 71, 55 intersects with building footprint(s).
# Tile 71, 56 intersects with building footprint(s).
# Tile 71, 57 intersects with building footprint(s).
# Tile 71, 58 intersects with building footprint(s).
# Tile 71, 59 intersects with building footprint(s).
# Tile 71, 60 intersects with building footprint(s).
# Tile 71, 61 intersects with building footprint(s).
# Tile 71, 62 intersects with building footprint(s).
# Tile 71, 63 intersects with building footprint(s).
# Tile 71, 64 intersects with building footprint(s).
# Tile 71, 65 intersects with building footprint(s).
# Tile 71, 66 intersects with building footprint(s).
# Tile 71, 67 intersects with building footprint(s).
# Tile 71, 68 intersects with building footprint(s).
# Tile 71, 69 intersects with building footprint(s).
# Tile 71, 70 intersects with building footprint(s).
# Tile 71, 71 intersects with building footprint(s).
# Tile 71, 72 intersects with building footprint(s).
# Tile 71, 73 intersects with building footprint(s).
# Tile 71, 74 intersects with building footprint(s).
# Tile 71, 75 intersects with building footprint(s).
# Tile 71, 76 intersects with building footprint(s).
# Tile 71, 77 intersects with building footprint(s).
# Tile 71, 78 intersects with building footprint(s).
# Tile 71, 79 intersects with building footprint(s).
# Tile 71, 80 intersects with building footprint(s).
# Tile 71, 81 intersects with building footprint(s).
# Tile 71, 82 intersects with building footprint(s).
# Tile 71, 83 intersects with building footprint(s).
# Tile 71, 84 intersects with building footprint(s).
# Tile 71, 86 intersects with building footprint(s).
# Tile 71, 87 intersects with building footprint(s).
# Tile 71, 88 intersects with building footprint(s).
# Tile 71, 89 intersects with building footprint(s).
# Tile 71, 90 intersects with building footprint(s).
# Tile 71, 91 intersects with building footprint(s).
# Tile 71, 92 intersects with building footprint(s).
# Tile 71, 93 intersects with building footprint(s).
# Tile 71, 94 intersects with building footprint(s).
# Tile 71, 95 intersects with building footprint(s).
# Tile 71, 96 intersects with building footprint(s).
# Tile 71, 97 intersects with building footprint(s).
# Tile 71, 98 intersects with building footprint(s).
# Tile 71, 99 intersects with building footprint(s).
# Tile 71, 100 intersects with building footprint(s).
# Tile 71, 101 intersects with building footprint(s).
# Tile 71, 102 intersects with building footprint(s).
# Tile 71, 103 intersects with building footprint(s).
# Tile 71, 104 intersects with building footprint(s).
# Tile 71, 105 intersects with building footprint(s).
# Tile 71, 106 intersects with building footprint(s).
# Tile 71, 108 intersects with building footprint(s).
# Tile 71, 115 intersects with building footprint(s).
# Tile 71, 116 intersects with building footprint(s).
# Tile 71, 117 intersects with building footprint(s).
# Tile 71, 118 intersects with building footprint(s).
# Tile 71, 119 intersects with building footprint(s).
# Tile 71, 120 intersects with building footprint(s).
# Tile 71, 121 intersects with building footprint(s).
# Tile 71, 122 intersects with building footprint(s).
# Tile 71, 123 intersects with building footprint(s).
# Tile 71, 124 intersects with building footprint(s).
# Tile 71, 125 intersects with building footprint(s).
# Tile 71, 126 intersects with building footprint(s).
# Tile 71, 127 intersects with building footprint(s).
# Tile 71, 128 intersects with building footprint(s).
# Tile 71, 129 intersects with building footprint(s).
# Tile 71, 130 intersects with building footprint(s).
# Tile 71, 131 intersects with building footprint(s).
# Tile 71, 132 intersects with building footprint(s).
# Tile 71, 133 intersects with building footprint(s).
# Tile 71, 134 intersects with building footprint(s).
# Tile 71, 135 intersects with building footprint(s).
# Tile 71, 136 intersects with building footprint(s).
# Tile 71, 137 intersects with building footprint(s).
# Tile 71, 138 intersects with building footprint(s).
# Tile 72, 11 intersects with building footprint(s).
# Tile 72, 15 intersects with building footprint(s).
# Tile 72, 16 intersects with building footprint(s).
# Tile 72, 17 intersects with building footprint(s).
# Tile 72, 18 intersects with building footprint(s).
# Tile 72, 19 intersects with building footprint(s).
# Tile 72, 20 intersects with building footprint(s).
# Tile 72, 21 intersects with building footprint(s).
# Tile 72, 22 intersects with building footprint(s).
# Tile 72, 23 intersects with building footprint(s).
# Tile 72, 29 intersects with building footprint(s).
# Tile 72, 30 intersects with building footprint(s).
# Tile 72, 31 intersects with building footprint(s).
# Tile 72, 32 intersects with building footprint(s).
# Tile 72, 33 intersects with building footprint(s).
# Tile 72, 34 intersects with building footprint(s).
# Tile 72, 41 intersects with building footprint(s).
# Tile 72, 42 intersects with building footprint(s).
# Tile 72, 43 intersects with building footprint(s).
# Tile 72, 44 intersects with building footprint(s).
# Tile 72, 45 intersects with building footprint(s).
# Tile 72, 46 intersects with building footprint(s).
# Tile 72, 47 intersects with building footprint(s).
# Tile 72, 48 intersects with building footprint(s).
# Tile 72, 49 intersects with building footprint(s).
# Tile 72, 50 intersects with building footprint(s).
# Tile 72, 51 intersects with building footprint(s).
# Tile 72, 52 intersects with building footprint(s).
# Tile 72, 53 intersects with building footprint(s).
# Tile 72, 54 intersects with building footprint(s).
# Tile 72, 55 intersects with building footprint(s).
# Tile 72, 56 intersects with building footprint(s).
# Tile 72, 57 intersects with building footprint(s).
# Tile 72, 58 intersects with building footprint(s).
# Tile 72, 59 intersects with building footprint(s).
# Tile 72, 60 intersects with building footprint(s).
# Tile 72, 61 intersects with building footprint(s).
# Tile 72, 62 intersects with building footprint(s).
# Tile 72, 63 intersects with building footprint(s).
# Tile 72, 64 intersects with building footprint(s).
# Tile 72, 65 intersects with building footprint(s).
# Tile 72, 66 intersects with building footprint(s).
# Tile 72, 67 intersects with building footprint(s).
# Tile 72, 68 intersects with building footprint(s).
# Tile 72, 69 intersects with building footprint(s).
# Tile 72, 70 intersects with building footprint(s).
# Tile 72, 71 intersects with building footprint(s).
# Tile 72, 72 intersects with building footprint(s).
# Tile 72, 73 intersects with building footprint(s).
# Tile 72, 74 intersects with building footprint(s).
# Tile 72, 75 intersects with building footprint(s).
# Tile 72, 76 intersects with building footprint(s).
# Tile 72, 77 intersects with building footprint(s).
# Tile 72, 78 intersects with building footprint(s).
# Tile 72, 79 intersects with building footprint(s).
# Tile 72, 80 intersects with building footprint(s).
# Tile 72, 81 intersects with building footprint(s).
# Tile 72, 82 intersects with building footprint(s).
# Tile 72, 83 intersects with building footprint(s).
# Tile 72, 84 intersects with building footprint(s).
# Tile 72, 85 intersects with building footprint(s).
# Tile 72, 86 intersects with building footprint(s).
# Tile 72, 87 intersects with building footprint(s).
# Tile 72, 88 intersects with building footprint(s).
# Tile 72, 89 intersects with building footprint(s).
# Tile 72, 90 intersects with building footprint(s).
# Tile 72, 91 intersects with building footprint(s).
# Tile 72, 92 intersects with building footprint(s).
# Tile 72, 93 intersects with building footprint(s).
# Tile 72, 94 intersects with building footprint(s).
# Tile 72, 95 intersects with building footprint(s).
# Tile 72, 96 intersects with building footprint(s).
# Tile 72, 97 intersects with building footprint(s).
# Tile 72, 98 intersects with building footprint(s).
# Tile 72, 99 intersects with building footprint(s).
# Tile 72, 100 intersects with building footprint(s).
# Tile 72, 101 intersects with building footprint(s).
# Tile 72, 102 intersects with building footprint(s).
# Tile 72, 103 intersects with building footprint(s).
# Tile 72, 104 intersects with building footprint(s).
# Tile 72, 105 intersects with building footprint(s).
# Tile 72, 106 intersects with building footprint(s).
# Tile 72, 109 intersects with building footprint(s).
# Tile 72, 112 intersects with building footprint(s).
# Tile 72, 113 intersects with building footprint(s).
# Tile 72, 114 intersects with building footprint(s).
# Tile 72, 115 intersects with building footprint(s).
# Tile 72, 116 intersects with building footprint(s).
# Tile 72, 117 intersects with building footprint(s).
# Tile 72, 118 intersects with building footprint(s).
# Tile 72, 119 intersects with building footprint(s).
# Tile 72, 120 intersects with building footprint(s).
# Tile 72, 121 intersects with building footprint(s).
# Tile 72, 122 intersects with building footprint(s).
# Tile 72, 123 intersects with building footprint(s).
# Tile 72, 124 intersects with building footprint(s).
# Tile 72, 125 intersects with building footprint(s).
# Tile 72, 126 intersects with building footprint(s).
# Tile 72, 127 intersects with building footprint(s).
# Tile 72, 128 intersects with building footprint(s).
# Tile 72, 129 intersects with building footprint(s).
# Tile 72, 130 intersects with building footprint(s).
# Tile 72, 131 intersects with building footprint(s).
# Tile 72, 132 intersects with building footprint(s).
# Tile 72, 133 intersects with building footprint(s).
# Tile 72, 134 intersects with building footprint(s).
# Tile 72, 135 intersects with building footprint(s).
# Tile 72, 136 intersects with building footprint(s).
# Tile 72, 137 intersects with building footprint(s).
# Tile 72, 138 intersects with building footprint(s).
# Tile 72, 142 intersects with building footprint(s).
# Tile 72, 143 intersects with building footprint(s).
# Tile 72, 144 intersects with building footprint(s).
# Tile 73, 12 intersects with building footprint(s).
# Tile 73, 13 intersects with building footprint(s).
# Tile 73, 15 intersects with building footprint(s).
# Tile 73, 16 intersects with building footprint(s).
# Tile 73, 17 intersects with building footprint(s).
# Tile 73, 18 intersects with building footprint(s).
# Tile 73, 19 intersects with building footprint(s).
# Tile 73, 20 intersects with building footprint(s).
# Tile 73, 21 intersects with building footprint(s).
# Tile 73, 22 intersects with building footprint(s).
# Tile 73, 23 intersects with building footprint(s).
# Tile 73, 24 intersects with building footprint(s).
# Tile 73, 29 intersects with building footprint(s).
# Tile 73, 30 intersects with building footprint(s).
# Tile 73, 31 intersects with building footprint(s).
# Tile 73, 33 intersects with building footprint(s).
# Tile 73, 34 intersects with building footprint(s).
# Tile 73, 41 intersects with building footprint(s).
# Tile 73, 42 intersects with building footprint(s).
# Tile 73, 43 intersects with building footprint(s).
# Tile 73, 44 intersects with building footprint(s).
# Tile 73, 45 intersects with building footprint(s).
# Tile 73, 46 intersects with building footprint(s).
# Tile 73, 47 intersects with building footprint(s).
# Tile 73, 48 intersects with building footprint(s).
# Tile 73, 49 intersects with building footprint(s).
# Tile 73, 50 intersects with building footprint(s).
# Tile 73, 51 intersects with building footprint(s).
# Tile 73, 52 intersects with building footprint(s).
# Tile 73, 53 intersects with building footprint(s).
# Tile 73, 54 intersects with building footprint(s).
# Tile 73, 55 intersects with building footprint(s).
# Tile 73, 56 intersects with building footprint(s).
# Tile 73, 57 intersects with building footprint(s).
# Tile 73, 58 intersects with building footprint(s).
# Tile 73, 59 intersects with building footprint(s).
# Tile 73, 60 intersects with building footprint(s).
# Tile 73, 61 intersects with building footprint(s).
# Tile 73, 62 intersects with building footprint(s).
# Tile 73, 63 intersects with building footprint(s).
# Tile 73, 64 intersects with building footprint(s).
# Tile 73, 65 intersects with building footprint(s).
# Tile 73, 66 intersects with building footprint(s).
# Tile 73, 67 intersects with building footprint(s).
# Tile 73, 68 intersects with building footprint(s).
# Tile 73, 69 intersects with building footprint(s).
# Tile 73, 70 intersects with building footprint(s).
# Tile 73, 71 intersects with building footprint(s).
# Tile 73, 72 intersects with building footprint(s).
# Tile 73, 73 intersects with building footprint(s).
# Tile 73, 74 intersects with building footprint(s).
# Tile 73, 75 intersects with building footprint(s).
# Tile 73, 76 intersects with building footprint(s).
# Tile 73, 77 intersects with building footprint(s).
# Tile 73, 78 intersects with building footprint(s).
# Tile 73, 79 intersects with building footprint(s).
# Tile 73, 80 intersects with building footprint(s).
# Tile 73, 81 intersects with building footprint(s).
# Tile 73, 82 intersects with building footprint(s).
# Tile 73, 83 intersects with building footprint(s).
# Tile 73, 84 intersects with building footprint(s).
# Tile 73, 85 intersects with building footprint(s).
# Tile 73, 86 intersects with building footprint(s).
# Tile 73, 87 intersects with building footprint(s).
# Tile 73, 88 intersects with building footprint(s).
# Tile 73, 89 intersects with building footprint(s).
# Tile 73, 90 intersects with building footprint(s).
# Tile 73, 91 intersects with building footprint(s).
# Tile 73, 92 intersects with building footprint(s).
# Tile 73, 93 intersects with building footprint(s).
# Tile 73, 94 intersects with building footprint(s).
# Tile 73, 95 intersects with building footprint(s).
# Tile 73, 96 intersects with building footprint(s).
# Tile 73, 97 intersects with building footprint(s).
# Tile 73, 98 intersects with building footprint(s).
# Tile 73, 99 intersects with building footprint(s).
# Tile 73, 100 intersects with building footprint(s).
# Tile 73, 101 intersects with building footprint(s).
# Tile 73, 103 intersects with building footprint(s).
# Tile 73, 104 intersects with building footprint(s).
# Tile 73, 106 intersects with building footprint(s).
# Tile 73, 107 intersects with building footprint(s).
# Tile 73, 108 intersects with building footprint(s).
# Tile 73, 109 intersects with building footprint(s).
# Tile 73, 112 intersects with building footprint(s).
# Tile 73, 113 intersects with building footprint(s).
# Tile 73, 114 intersects with building footprint(s).
# Tile 73, 115 intersects with building footprint(s).
# Tile 73, 116 intersects with building footprint(s).
# Tile 73, 117 intersects with building footprint(s).
# Tile 73, 118 intersects with building footprint(s).
# Tile 73, 119 intersects with building footprint(s).
# Tile 73, 120 intersects with building footprint(s).
# Tile 73, 121 intersects with building footprint(s).
# Tile 73, 122 intersects with building footprint(s).
# Tile 73, 123 intersects with building footprint(s).
# Tile 73, 124 intersects with building footprint(s).
# Tile 73, 125 intersects with building footprint(s).
# Tile 73, 126 intersects with building footprint(s).
# Tile 73, 127 intersects with building footprint(s).
# Tile 73, 128 intersects with building footprint(s).
# Tile 73, 129 intersects with building footprint(s).
# Tile 73, 131 intersects with building footprint(s).
# Tile 73, 132 intersects with building footprint(s).
# Tile 73, 133 intersects with building footprint(s).
# Tile 73, 134 intersects with building footprint(s).
# Tile 73, 135 intersects with building footprint(s).
# Tile 73, 136 intersects with building footprint(s).
# Tile 73, 137 intersects with building footprint(s).
# Tile 73, 138 intersects with building footprint(s).
# Tile 73, 140 intersects with building footprint(s).

# %%
building_footprints_gdf.head()

# %%
def convert_tiff_to_jpeg(input_dir,output_dir):
    # check if output_dir exists, if not create it
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for filename in os.listdir(input_dir):
        # check if file is an image (ends with .tif)
        if filename.endswith('.tif'):
            img = Image.open(os.path.join(input_dir, filename))
        
            # check if image is RGB mode, if not convert it
            if img.mode != 'RGB':
                img = img.convert('RGB')
        
            # create new filename, replace .tif with .jpg
            output_filename = os.path.splitext(filename)[0] + '.jpg'
        
            # save the image in JPEG format
            img.save(os.path.join(output_dir, output_filename), 'JPEG')
    print("Conversion from TIFF to JPEG completed.")

# %%
input_dir = "../data/intermediate/Pre_Event_Grids_In_TIFF_all_buildings"
output_dir = "../data/intermediate/Pre_Event_Grids_In_JPEG_all_buildings"
convert_tiff_to_jpeg(input_dir,output_dir)
# Out:
# Conversion from TIFF to JPEG completed.
